# %% [markdown]
# 1.  Use Copilot to identify and summarize missing values in the dataset.
#
#     Answer-> Afetr applying the copilot in the dataset we identify and summarise 40 missing values in the dataset.(COUNTBLANK)
#
# 2. Use Copilot to fill missing values in the Region and Category columns.
#
#     Answer-> steps to fill missing values in the region and category are:
#
#     1- select the region or category column.
#     2- ctrl+g-> special.
#     3- select BLANK.
#     4- = UP ARROW ENTER
#
# 3.  Fill missing numeric values in the Unit sold and Unit price columns.
#
#     Answer-> 1- Select the empty cell.2- calculate the average.3- Copy the average value.4- Select the Unit Sold / Unit Price column.5-Press Ctrl + G → Special → Blanks → OK
#
# Press Ctrl + V → Enter
#
# 4.  Create a new calculated column Total Revenue.
#
#     Answer-> 1- Insert a new column and name it Total Revenue.
#              2- multiply unit price x unit sold.
#
#
# 5.  Use Copilot to find the total price of Order ID = ‘ORD0123’.
#
#     Answer-> the total price of order id- 0123 is= 56029.05
#
# 6.  Use Copilot to generate a summary chart of average profit by region.
#
#     Answer-> the average profit by region is = 53218.97.
#
# 7.  Create a pivot table summarizing total sales by category and region.
#
#     Answer-> the grand total sales of category and region is = 350.
#
# 8. Build a dashboard combining key KPIs and charts.
#
#     Answer-> 1- Identify Key KPIs
#              2- Create KPI Calculations.
#
# 9. Use Copilot to generate a summary report.
#
#     Answer-> Prepare the Data, Open Copilot, Enter an Effective Prompt,Review Copilot’s Output.
